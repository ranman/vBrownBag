# %%
data = {'created_at': 'Thu Apr 04 01:10:29 +0000 2019', 'id': 1113609750778994688, 'id_str': '1113609750778994688', 'text': 'Fucking periodt.', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 165546111, 'id_str': '165546111', 'name': 'bullshitiana', 'screen_name': 'SlayOnYou', 'location': 'slayonyou@yahoo.com', 'url': 'http://slayonyou.com', 'description': 'hydrate yourself, take your vitamins & chase your bag sis | @SlayIist ✨ | cashapp: $SlayOnYou', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 27574, 'friends_count': 20793, 'listed_count': 41, 'favourites_count': 1865, 'statuses_count': 12531, 'created_at': 'Sun Jul 11 22:22:44 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F01109', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'BD3D4E', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1108503299936960512/X-e0cGkw_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1108503299936960512/X-e0cGkw_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/165546111/1553122780', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1112889450084945921, 'quoted_status_id_str': '1112889450084945921', 'quoted_status': {'created_at': 'Tue Apr 02 01:28:16 +0000 2019', 'id': 1112889450084945921, 'id_str': '1112889450084945921', 'text': 'Females break more bread in relationships, females show more support, love &amp; appreciation in a relationship, female… https://t.co/Nczwe35r9W', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1066843587877441536, 'id_str': '1066843587877441536', 'name': 'mini dearra🧚🏾\u200d♀️', 'screen_name': 'therealmarjav', 'location': 'Kansas City, MO', 'url': 'http://youtube.com/marjaydashaeTV', 'description': 'Instagram: @therealmarjaveya | 1.4k+ subbies | Subscribe⬇️', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2531, 'friends_count': 81, 'listed_count': 6, 'favourites_count': 2173, 'statuses_count': 2236, 'created_at': 'Sun Nov 25 23:58:27 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1105126114362617856/EuKmvzHB_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1105126114362617856/EuKmvzHB_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1066843587877441536/1553552597', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Females break more bread in relationships, females show more support, love &amp; appreciation in a relationship, females will stay solid while they boyfriend down. Soon as the girlfriend down she “too needy.” A NIGGA COULD NEVER. Y’all don’t wanna talk about it tho.', 'display_text_range': [0, 266], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}}, 'quote_count': 1565, 'reply_count': 230, 'retweet_count': 13554, 'favorite_count': 38513, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/Nczwe35r9W', 'expanded_url': 'https://twitter.com/i/web/status/1112889450084945921', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [121, 144]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en'}, 'quoted_status_permalink': {'url': 'https://t.co/lzXvSq0cfn', 'expanded': 'https://twitter.com/therealmarjav/status/1112889450084945921', 'display': 'twitter.com/therealmarjav/…'}, 'is_quote_status': True, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1554340229111'}

# %%
# Out:
# {'created_at': 'Thu Apr 04 01:10:29 +0000 2019',
#  'id': 1113609750778994688,
#  'id_str': '1113609750778994688',
#  'text': 'Fucking periodt.',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 165546111,
#   'id_str': '165546111',
#   'name': 'bullshitiana',
#   'screen_name': 'SlayOnYou',
#   'location': 'slayonyou@yahoo.com',
#   'url': 'http://slayonyou.com',
#   'description': 'hydrate yourself, take your vitamins & chase your bag sis | @SlayIist ✨ | cashapp: $SlayOnYou',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 27574,
#   'friends_count': 20793,
#   'listed_count': 41,
#   'favourites_count': 1865,
#   'statuses_count': 12531,
# ...
